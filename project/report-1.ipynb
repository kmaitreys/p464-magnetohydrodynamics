# %%
include("src/GalacticDynamo.jl")
# Out:
# WARNING: replacing module GalacticDynamo.
# Main.GalacticDynamo

# %%
dt = 0.01
r_min = 0.0
r_max = 10.0

t_min = 0.0
t_max = 5.0

dr = 0.01

# Create the radial grid
r = r_min:dr:r_max

scale_height = 0.1 * ones(size(r))

t = t_min:dt:t_max
# Out:
# 0.64464449506926

# %%
# Initial conditions
B_r = @. sin(0.4 * sin(10π * r / (r_max - dr)) + π * r / (r_max - dr))
B_ϕ = @. -sin(0.4 * sin(4π * r / (r_max - dr)) + π * r / (r_max - dr))
# Out:
# [0.0, 0.015720966117009724, 0.03142561600389717, 0.047097677358310795, 0.06272096546126077, 0.07827942629082416, 0.09375717882917567, 0.10913855630546059, 0.12440814612663278, 0.13955082826017703, 0.15455181184648545, 0.1693966698344035, 0.18407137145092195, 0.19856231233497232, 0.212856342185572, 0.22694078979593948, 0.24080348536742863, 0.25443278001997466, 0.2678175624389702, 0.28094727262185437, 0.29381191271096885, 0.30640205492219363, 0.31870884660128795, 0.33072401246154975, 0.3424398540771487, 0.35384924672614226, 0.3649456336955644, 0.3757230181779696, 0.3861759529042876, 0.3962995276717048, 0.40608935493745923, 0.41554155365986245, 0.4246527315764999, 0.43341996611640304, 0.4418407841480226, 0.4499131407680935, 0.45763539733798236, 0.46500629897391976, 0.47202495169568587, 0.478690799434917, 0.48500360109931756, 0.4909634078827888, 0.4965705410039109, 0.5018255700464525, 0.5067292920657346, 0.511282711613849, 0.5154870218250375, 0.5193435866900996, 0.5228539246355971, 0.526
# ...
